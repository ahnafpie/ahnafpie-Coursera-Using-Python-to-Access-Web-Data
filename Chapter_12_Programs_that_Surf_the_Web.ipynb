# %%
# get ASCII numbers
# ord() means ordinary method
print(ord('h'))
print(ord('H'))
print(ord('9'))
# Out:
# 104
# 72
# 57

# %%
# encode() converts string into byte class
print(('hello'.encode()))
print(type(('hello'.encode())))
# Out:
# b'hello'
# <class 'bytes'>

# %%
# decode() converts byte class into string class
print((b'hello').decode())
print(type((b'hello').decode()))
# Out:
# hello
# <class 'str'>

# %%
# retrive webpages using urllib

import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

counts = {}
for line in fhand:
    words = line.decode().split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1
print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %%
# retriving html page
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('https://ahnafpie.github.io/mip/')

for line in fhand:
    print(line.decode().strip())
# Out:
# <!doctype html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <!-- Bootstrap CSS -->
# <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css"
# integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
# <!-- CSS -->
# <link rel="stylesheet" href="styles.css">
# <title>mip</title>
# <!-- Font-awesome -->
# <script src="https://kit.fontawesome.com/699e0991c9.js" crossorigin="anonymous"></script>
# <!-- navbar-toggler-color -->
# <style>
# /* Set the border color */
# .custom-toggler.navbar-toggler {
# border: 0;
# }
# /* Setting the stroke */
# .custom-toggler .navbar-toggler-icon {
# ...
